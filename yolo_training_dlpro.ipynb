# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15833, done.
# remote: Total 15833 (delta 0), reused 0 (delta 0), pack-reused 15833
# Receiving objects: 100% (15833/15833), 14.39 MiB | 16.19 MiB/s, done.
# Resolving deltas: 100% (10666/10666), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
#verify cuda

! /usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
# ...

# %%
# !pwd
# Out:
# /content/darknet

# %%
cd ..
# Out:
# /content

# %%
# !pwd
# Out:
# /content

# %%
# !cp /content/drive/MyDrive/DL-por/obj.zip ../

# %%
# !unzip ../obj.zip -d data/
# Out:
# Archive:  ../obj.zip
#   inflating: data/obj/classes.txt
#   inflating: data/obj/img1.png
#   inflating: data/obj/img1.txt
#   inflating: data/obj/img10.png
#   inflating: data/obj/img10.txt
#   inflating: data/obj/img11.png
#   inflating: data/obj/img11.txt
#   inflating: data/obj/img12.png
#   inflating: data/obj/img12.txt
#   inflating: data/obj/img13.png
#   inflating: data/obj/img13.txt
#   inflating: data/obj/img2.png
#   inflating: data/obj/img2.txt
#   inflating: data/obj/img3.png
#   inflating: data/obj/img3.txt
#   inflating: data/obj/img4.png
#   inflating: data/obj/img4.txt
#   inflating: data/obj/img5.png
#   inflating: data/obj/img5.txt
#   inflating: data/obj/img6.png
#   inflating: data/obj/img6.txt
#   inflating: data/obj/img8.png
#   inflating: data/obj/img8.txt
#   inflating: data/obj/img9.png
#   inflating: data/obj/img9.txt

# %%
# !cp /content/drive/MyDrive/DL-por/obj.names.txt ./data

# %%
# !cp /content/drive/MyDrive/DL-por/obj.data.txt ./data

# %%
# !cp /content/drive/MyDrive/DL-por/yolov3_custom.cfg ./data

# %%
# !cp /content/drive/MyDrive/DL-por/generate_train.py ./

# %%
# !python generate_train.py

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2024-03-27 13:32:08--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  34.9MB/s    in 4.8s
#
# 2024-03-27 13:36:03 (32.5 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !pwd
# Out:
# /content

# %%
cd darknet
# Out:
# /content/darknet

# %%
# !./darknet detector train  /content/data/obj.data.txt /content/data/yolov3_custom.cfg /content/darknet53.conv.74 -dont_show
# Out:
#  CUDA-version: 12020 (12020), cuDNN: 8.9.6, GPU count: 1
#  OpenCV version: 4.5.4
# valid: Using default 'data/train.txt'
# yolov3_custom
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 4, batch = 32, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
# !pwd
# Out:
# /content/darknet

# %%
cd ..
# Out:
# /content

# %%
# !/content/darknet/darknet detector train  /content/data/obj.data.txt /content/data/yolov3_custom.cfg /content/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.165147, iou_loss = 0.000000, total_loss = 0.165147
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.612282), count: 14, class_loss = 2.835147, iou_loss = 2.106076, total_loss = 4.941224
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.577065), count: 77, class_loss = 19.631155, iou_loss = 10.964727, total_loss = 30.595882
#  total_bbox = 530321, rewritten_bbox = 0.009051 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.488597), count: 4, class_loss = 0.360780, iou_loss = 1.077982, total_loss = 1.438762
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.662204), count: 42, class_loss = 6.447720, iou_loss = 4.257299, total_loss = 10.705019
# ...
